# %% [markdown]
# # [RPA] HWPX 포맷에 대한 연구
# ---

# %% [markdown]
# ## 1. About Properties

# %%
# test
import pandas as pd
import logging

logging.error('Hello World!')
df = pd.DataFrame(data={'name': ['woo', 'choo'], 'age': [22, 21], 'dept': ['RPA', 'RPA']})

print(df)
# Out:
# ERROR:root:Hello World!
#    name  age dept
# 0   woo   22  RPA
# 1  choo   21  RPA
